# %%
# !python -m pip install matplotlib
# !python -m pip install opencv-python
# !python -m pip install scikit-image
# !python -m pip install pillow
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ---------------------------------------- 0.1/7.5 MB 1.2 MB/s eta 0:00:07
#       --------------------------------------- 0.2/7.5 MB 1.1 MB/s eta 0:00:07
#      - -------------------------------------- 0.2/7.5 MB 1.2 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/7.5 MB 1.3 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/7.5 MB 1.4 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/7.5 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.4/7.5 MB 1.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/7.5 MB 1.3 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/7.5 MB 1.2 MB/s eta 0:00:06
# ...

# %%
############  IMAGE PROCESSING & COMPUTER VISION  ###########

# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
img1 = plt.imread("robot2.jpg")
plt.imshow(img1)
plt.axis("off")
plt.show()

# %%
img2 = cv2.imread("robot1.jpg")
cv2.imshow('image',img2)
cv2.waitKey(0)
# Out:
# -1

# %%
img3 = skimage.io.imread("robot2.jpg")
img3.shape
type(img3)
# Out:
# numpy.ndarray

# %% [markdown]
# import numpy as np

# %%
import numpy as np
r1 = np.random.randint(0,255,(500,500,3))
plt.imshow(r1)

# %%
r2 = np.random.randint(0,255,(50,50))
plt.imshow(r2)

# %%
r3 = np.random.randint(0,255,(25,25))
plt.imshow(r1)

# %%
img = np.ones((50,50,3), dtype='uint8') * 255
img[:25,:25,1:] = 0 #img[:25,:25,1:] * 0
img[:25,25:,::2] = 0 #img[:25,:25,::2] * 0
img[25:,:25,:2] = 0 #img[25:,:25,:2] * 0
img[25:,25:,2:] = 0 #img[25:,25:,2:] * 0
plt.imshow(img)

# %%
plt.imsave("robot1.jpg",img)

# %%
skimage.io.imsave("robot.jpg",img)

# %%
cv2.imwrite("robot.jpg",img)
# Out:
# True

# %%
cv2.imshow('image',img2)
cv2.waitKey(0)
# Out:
# -1

# %%
#plt.imshow(img2)
plt.imshow(img1[:,:,::-1])

# %%
# image type conversion
# geometric transformation
# image arithmetic / brightness / contrast adjustment
# morphology
# features detection


plt.imshow(img1[:,:,::-1])

# %%
img_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (600, 600)

# %%
th, img_bin = cv2.threshold(img_gray, 120,255,cv2.THRESH_BINARY)
img_bin.shape
# Out:
# (600, 600)

# %%
plt.imshow(img_bin, cmap='gray')

# %%
plt.imshow(img1[:200, 200:400,::-1]),
# Out:
# (<matplotlib.image.AxesImage at 0x3ff721f940>,)

# %%
x,y,w,h = (50,150,80,140)
plt.imshow(img1[y:y+h, x:x+w, ::-1])
plt.show()


x1, y1,x2,y2 = (50,150,270,210)
plt.imshow(img1[y1:y2, x1:x2, ::-1])
plt.show()

y1,x1,y2,x2 = (50,150,270,210)
plt.imshow(img1[y1:y2, x1:x2, ::-1])
plt.show()

# %%
img_large = cv2.resize(img1, [1500,1500],interpolation=cv2.INTER_CUBIC)
img_large.shape
plt.imshow(img_large)

# %%
img_large = cv2.resize(img1, [1500,1500],interpolation=cv2.INTER_CUBIC)
img_large.shape

img_small = cv2.resize(img1, (0,0), fx=0.25, fy=0.25,interpolation=cv2.INTER_CUBIC)
img_small.shape
plt.imshow(img_small)

# %%
img_90 = cv2.rotate(img1, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_90[:,:,::-1])

# %%
plt.subplot(1,3,1)
plt.title('original')
plt.imshow(img1[:,:,::-1]) 

plt.subplot(1,3,2)
plt.title('Brightness')
plt.imshow(cv2.add(img1[:,:,::-1], 20))


plt.subplot(1,3,3)
plt.title('darkened')
plt.imshow(cv2.subtract(img1[:,:,::-1], 20))

# %%
img_cntbrt = cv2.convertScaleAbs(img1, alpha = 1.25, beta = 10)
plt.imshow(img_cntbrt[:,:,::-1]) ############
