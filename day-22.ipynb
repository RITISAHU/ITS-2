# %%
# !python -m pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/293.3 kB ? eta -:--:--
#      ------------ -------------------------- 92.2/293.3 kB 1.3 MB/s eta 0:00:01
#      --------------- ---------------------- 122.9/293.3 kB 1.0 MB/s eta 0:00:01
#      ------------------------- ------------ 194.6/293.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.25.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritik\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ritik\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ritik\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ritik\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.shape
# Out:
# (200, 4)

# %%
sns.scatterplot(x=data.TV,y=data.Sales)
plt.show()

# %%
sns.scatterplot(x=data.Radio,y=data.Sales)
plt.show()

# %%
sns.scatterplot(x=data.Newspaper,y=data.Sales)
plt.show()

# %%
# URL of the dataset
url = 'https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv'

# Load the dataset from the URL
data = pd.read_csv(url)

# ploting 
plt.xlabel('TV')
plt.ylabel('sales')
# creating first subplot row , column , plot1 
plt.subplot(3,1,1)
plt.title('Advertinsing data')
plt.scatter(data.TV,data.Sales)
plt.subplot(3,1,2)
plt.scatter(data.Radio,data.Sales)
plt.subplot(3,1,3)
plt.scatter(data.Newspaper,data.Sales)
plt.show()
# Out:
# C:\Users\RITIK\AppData\Local\Temp\ipykernel_6200\1120111438.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,1,1)

# %%
# URL of the dataset
url = 'https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv'

# Load the dataset from the URL
data = pd.read_csv(url)

# Scatter plot for subplot 1
plt.subplot(3,1,1)
plt.scatter(data['TV'], data['Sales'])
plt.title('Tv and Sales')
plt.xlabel('TV')
plt.ylabel('Sales')

# Scatter plot for subplot 2
plt.subplot(3,1,2)
plt.scatter(data['Radio'], data['Sales'])
plt.title('Radio and Sales')
plt.xlabel('Radio')
plt.ylabel('Sales')

# Scatter plot for subplot 3
plt.subplot(3,1,3)
plt.scatter(data['Newspaper'], data['Sales'])
plt.title('Newspaper and Sales')
plt.xlabel('Newspaper')
plt.ylabel('Sales')


# Show the plots
plt.show()

# %%
# scikit learn 
#1 dataset
#2 data category
#3 implemented
#

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URL of the dataset
url = 'https://raw.githubusercontent.com/redashu/Datasets/master/advertising.csv'

# Load the dataset from the URL
data = pd.read_csv(url)



# Scatter plot for TV , Sales
plt.subplot(3, 1, 1)  # 3 row, 1 columns, first subplot
plt.scatter(data['TV'], data['Sales'])
plt.title('TV and Sales')
plt.xlabel('TV')
plt.ylabel('Sales')

# Scatter plot for Radio , Sales
plt.subplot(3, 1, 2)  # 3 row, 1 columns, second subplot
plt.scatter(data['Radio'], data['Sales'])
plt.title('Radio and Sales')
plt.xlabel('Radio')
plt.ylabel('Sales')

# Scatter plot for Newspaper , Sales
plt.subplot(3, 1, 3)  # 3 row, 1 columns, third subplot
plt.scatter(data['Newspaper'], data['Sales'])
plt.title('Newspaper and Sales')
plt.xlabel('Newspaper')
plt.ylabel('Sales')


plt.show()
